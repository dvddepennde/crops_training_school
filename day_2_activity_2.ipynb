# %% [markdown]
# ### **Load the dataset:**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('https://raw.githubusercontent.com/dvddepennde/crops_training_school/main/nutrients_csvfile.csv')

data['Grams'] =data['Grams'].str.replace(',','')
data['Grams'] = data['Grams'].astype(int)

data['Calories'] =data['Calories'].str.replace(',','')
data['Calories'] =data['Calories'].str.replace('-','')
data = data.dropna(subset=['Calories'])
data['Calories'] = data['Calories'].astype(int)


data['Protein'] =data['Protein'].str.replace(',','')
data['Protein'] =data['Protein'].str.replace('t','')
data = data[data['Protein'] != '']
data = data.dropna(subset=['Protein'])
data['Protein'] = data['Protein'].astype(int)


data['Fat'] =data['Fat'].str.replace(',','')
data['Fat'] =data['Fat'].str.replace('t','')
data['Fat'] =data['Fat'].str.replace("'",'')

data = data[data['Fat'] != '']
data = data.dropna(subset=['Fat'])
data['Fat'] = data['Fat'].astype(int)

data['Sat.Fat'] =data['Sat.Fat'].str.replace(',','')
data['Sat.Fat'] =data['Sat.Fat'].str.replace('t','')
data['Sat.Fat'] =data['Sat.Fat'].str.replace("'",'')

data = data[data['Sat.Fat'] != '']
data = data.dropna(subset=['Sat.Fat'])
data['Sat.Fat'] = data['Sat.Fat'].astype(int)


data['Fiber'] =data['Fiber'].str.replace(',','')
data['Fiber'] =data['Fiber'].str.replace('t','')
data['Fiber'] =data['Fiber'].str.replace("'",'')
data['Fiber'] =data['Fiber'].str.replace("a",'')

data = data[data['Fiber'] != '']
data = data.dropna(subset=['Fiber'])
data['Fiber'] = data['Fiber'].astype(float)


data['Carbs'] =data['Carbs'].str.replace(',','')
data['Carbs'] =data['Carbs'].str.replace('t','')
data['Carbs'] =data['Carbs'].str.replace("'",'')
data['Carbs'] =data['Carbs'].str.replace(".",'')
data['Carbs'] =data['Carbs'].str.replace("a",'')

data = data[data['Carbs'] != '']
data = data.dropna(subset=['Carbs'])
data['Carbs'] = data['Carbs'].astype(int)



data.head()
# Out:
#                     Food Measure  Grams  Calories  Protein  Fat  Sat.Fat  \
# 0             Cows' milk   1 qt.    976       660       32   40       36
# 2             Buttermilk   1 cup    246       127        9    5        4
# 3  Evaporated, undiluted   1 cup    252       345       16   20       18
# 4         Fortified milk  6 cups   1419      1373       89   42       23
# 5          Powdered milk   1 cup    103       515       27   28       24
#
#    Fiber  Carbs        Category
# 0    0.0     48  Dairy products
# 2    0.0     13  Dairy products
# 3    0.0     24  Dairy products
# 4    1.4    119  Dairy products
# 5    0.0     39  Dairy products

# %% [markdown]
# ## Activity
# In this section, you should be able to explore to explore the dataset by creating and displaying various graphs, allowing you to visualize and analyze the data properly.
#
# Remember, if you have any doubt ask your teachers David and Carmen ;)
